# %% [markdown]
# # Cancerous and Healthy Tissue Classifier through esophagus microscopic images

# %% [markdown]
# <a href="https://colab.research.google.com/drive/1JbMpw_nQaCq5WAZmY0iDWVEWWV4cgH9H?usp=sharing" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Challenge by Mauna Kea (Challenge Link: https://challengedata.ens.fr/participants/challenges/11/)

# %%
from IPython.display import Image

# %%
Image('https://raw.githubusercontent.com/contepablod/QCNNCancerClassifier/master/Esophagus%20Cancer.JPG')

# %% [markdown]
# ## 1. Load required libraries

# %%
import os
import random

import numpy as np
import pandas as pd

from skimage import io

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### 1.1 Required Functions

# %%
def matrix_confusion(yt, yp):
    data = {'Y_Real': yt,
            'Y_Prediccion': yp}

    df = pd.DataFrame(data, columns=['Y_Real','Y_Prediccion'])
    confusion_matrix = pd.crosstab(df['Y_Real'], df['Y_Prediccion'], rownames=['Real'], colnames=['Predicted'])
    sns.heatmap(confusion_matrix, annot=True, fmt='g')

    plt.show()

# %% [markdown]
# ## 2. Read Data

# %% [markdown]
# ### 2.1 Read Labels (Y)

# %%
data = pd.read_csv("https://raw.githubusercontent.com/AnIsAsPe/ClassificadorCancerEsofago/master/Datos/ClasesImagenes.csv", usecols=[1,2])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5063 entries, 0 to 5062
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   image_filename  5063 non-null   object
#  1   class_number    5063 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 79.2+ KB

# %%
data['class_number'].value_counts(sort=False)
# Out:
# class_number
# 0    1469
# 1    3594
# Name: count, dtype: int64

# %% [markdown]
# Class 0 belongs to Healthy Tissue y Class 1 to Cancerous Tissue

# %%
Y = data['class_number']

# %% [markdown]
# ### 2.2 Read Images (X)

# %%
data['image_filename']
# Out:
# 0          im_4_0.png
# 1         im_21_0.png
# 2          im_9_0.png
# 3          im_8_0.png
# 4         im_15_0.png
#             ...
# 5058    im_114_55.png
# 5059      im_7_55.png
# 5060     im_52_55.png
# 5061     im_10_55.png
# 5062    im_111_55.png
# Name: image_filename, Length: 5063, dtype: object

# %% [markdown]
# ## Images can be dowloaded from:
# https://github.com/contepablod/QCNNCancerClassifier/tree/master/CarpetaImagenes
#
# We read them from local disk

# %%
# path = "C:\\Users\\conte\\OneDrive\\Escritorio\\Colegio Bourbaki\\ML-AI-WA\\Perceptron\\CarpetaImagenes\\"

# %%
path = "Images\\"

# %%
# %time  img = data['image_filename'].apply(lambda x: io.imread(path + x, as_gray=True))
# Out:
# CPU times: total: 1min 38s
# Wall time: 1min 43s

# %% [markdown]
# - Dimension 0: 260 up-to-down pixels rows
# - Dimension 1: 260 left-to-right pixel columns

# %% [markdown]
# ####  Images to vectors

# %%
img.shape
# Out:
# (5063,)

# %%
img[0].shape
# Out:
# (260, 260)

# %%
IMG = np.stack(img, axis=0)
IMG.shape
# Out:
# (5063, 260, 260)

# %% [markdown]
# Then flatten the 2D matrix (260x260 pixels) of each image, to obtain one vector per image.

# %%
X = IMG.reshape(5063, -1) # se puede poner 67600 en vez de -1
X.shape
# Out:
# (5063, 67600)

# %% [markdown]
# ##### Image Visualizer

# %%
byClass = data.groupby('class_number')

n = 20
c = random.sample(byClass.get_group(1).index.tolist(), n)
s = random.sample(byClass.get_group(0).index.tolist(), n)


fig = plt.figure(figsize=(16, 8))
columns = 10
rows = 4
for i in range(0, columns * rows):
    fig.add_subplot(rows, columns, i+1)
    if i < 20:
        plt.imshow(img[c[i]], cmap='Greys_r')
        plt.title('Cancer')
        plt.xticks([])
        plt.yticks([])
    else:
        plt.imshow(img[s[i-20]], cmap='Greys_r')
        plt.title('Healthy Tissue')
        plt.xticks([])
        plt.yticks([])
plt.show()

# %% [markdown]
# ## 3. Perceptron Training

# %% [markdown]
# ### 3.1  Train and Test Sets creation

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.3,
                                                    shuffle=True, random_state=0)

# %%
print("Training set")
print("X: ", X_train.shape)
print("Y: ", y_train.shape)
unique, counts = np.unique(y_train, return_counts=True)
print('Healthy Tissue:        ', counts[0],'\nCancer: ', counts[1],'\n')


print("Test set")
print("X: ", X_test.shape)
print("Y: ", y_test.shape)
unique, counts = np.unique(y_test, return_counts=True)
print('Healthy Tissue:         ', counts[0],'\nCancer: ', counts[1],'\n')
# Out:
# Training set
# X:  (3544, 67600)
# Y:  (3544,)
# Healthy Tissue:         1043
# Cancer:  2501
#
# Test set
# X:  (1519, 67600)
# Y:  (1519,)
# Healthy Tissue:          426
# Cancer:  1093

# %% [markdown]
# ### 3.2  Perceptron Training

# %%
model_p = Perceptron(max_iter=50, random_state=0, verbose=True)
model_p.fit(X_train,y_train)
# Out:
# -- Epoch 1
# Norm: 1123.26, NNZs: 67600, Bias: -39.000000, T: 3544, Avg. loss: 1641.286726
# Total training time: 0.50 seconds.
# -- Epoch 2
# Norm: 1709.08, NNZs: 67600, Bias: -56.000000, T: 7088, Avg. loss: 1415.700003
# Total training time: 0.95 seconds.
# -- Epoch 3
# Norm: 2155.80, NNZs: 67600, Bias: -69.000000, T: 10632, Avg. loss: 1231.936834
# Total training time: 1.40 seconds.
# -- Epoch 4
# Norm: 2616.13, NNZs: 67600, Bias: -76.000000, T: 14176, Avg. loss: 1124.851144
# Total training time: 4.75 seconds.
# -- Epoch 5
# Norm: 3021.59, NNZs: 67600, Bias: -75.000000, T: 17720, Avg. loss: 1133.721658
# Total training time: 5.17 seconds.
# -- Epoch 6
# Norm: 3379.11, NNZs: 67600, Bias: -74.000000, T: 21264, Avg. loss: 971.851823
# Total training time: 5.66 seconds.
# -- Epoch 7
# Norm: 3724.07, NNZs: 67600, Bias: -66.000000, T: 24808, Avg. loss: 937.594908
# Total training time: 6.28 seconds.
# -- Epoch 8
# Norm: 4026.70, NNZs: 67600, Bias: -68.000000, T: 28352, Avg. loss: 855.373414
# Total training time: 6.82 seconds.
# -- Epoch 9
# Norm: 4353.32, NNZs: 67600, Bias: -69.000000, T: 31896, Avg. loss: 866.263533
# Total training time: 7.45 seconds.
# -- Epoch 10
# Norm: 4660.13, NNZs: 67600, Bias: -65.000000, T: 35440, Avg. loss: 776.228995
# Total training time: 7.92 seconds.
# -- Epoch 11
# Norm: 4921.06, NNZs: 67600, Bias: -61.000000, T: 38984, Avg. loss: 678.473853
# Total training time: 8.32 seconds.
# -- Epoch 12
# Norm: 5171.96, NNZs: 67600, Bias: -60.000000, T: 42528, Avg. loss: 699.998242
# Total training time: 8.81 seconds.
# -- Epoch 13
# Norm: 5430.28, NNZs: 67600, Bias: -63.000000, T: 46072, Avg. loss: 702.381738
# Total training time: 9.28 seconds.
# -- Epoch 14
# Norm: 5668.24, NNZs: 67600, Bias: -66.000000, T: 49616, Avg. loss: 671.321657
# Total training time: 12.32 seconds.
# -- Epoch 15
# Norm: 5874.92, NNZs: 67600, Bias: -60.000000, T: 53160, Avg. loss: 616.342931
# Total training time: 12.90 seconds.
# -- Epoch 16
# Norm: 6076.95, NNZs: 67600, Bias: -61.000000, T: 56704, Avg. loss: 594.252122
# Total training time: 13.29 seconds.
# -- Epoch 17
# Norm: 6269.64, NNZs: 67600, Bias: -60.000000, T: 60248, Avg. loss: 564.383660
# Total training time: 13.81 seconds.
# -- Epoch 18
# Norm: 6476.34, NNZs: 67600, Bias: -60.000000, T: 63792, Avg. loss: 565.665024
# Total training time: 14.26 seconds.
# -- Epoch 19
# Norm: 6689.34, NNZs: 67600, Bias: -58.000000, T: 67336, Avg. loss: 524.297755
# Total training time: 14.78 seconds.
# -- Epoch 20
# Norm: 6862.68, NNZs: 67600, Bias: -48.000000, T: 70880, Avg. loss: 511.356194
# Total training time: 15.34 seconds.
# -- Epoch 21
# Norm: 7028.38, NNZs: 67600, Bias: -49.000000, T: 74424, Avg. loss: 474.784911
# Total training time: 15.81 seconds.
# -- Epoch 22
# Norm: 7204.30, NNZs: 67600, Bias: -48.000000, T: 77968, Avg. loss: 476.401283
# Total training time: 16.28 seconds.
# -- Epoch 23
# Norm: 7387.32, NNZs: 67600, Bias: -60.000000, T: 81512, Avg. loss: 478.475253
# Total training time: 16.73 seconds.
# -- Epoch 24
# Norm: 7540.80, NNZs: 67600, Bias: -60.000000, T: 85056, Avg. loss: 424.364124
# Total training time: 17.19 seconds.
# -- Epoch 25
# Norm: 7695.07, NNZs: 67600, Bias: -57.000000, T: 88600, Avg. loss: 397.421738
# Total training time: 17.69 seconds.
# -- Epoch 26
# Norm: 7845.61, NNZs: 67600, Bias: -49.000000, T: 92144, Avg. loss: 416.331109
# Total training time: 18.29 seconds.
# -- Epoch 27
# Norm: 8000.78, NNZs: 67600, Bias: -46.000000, T: 95688, Avg. loss: 412.591219
# Total training time: 18.78 seconds.
# -- Epoch 28
# Norm: 8155.36, NNZs: 67600, Bias: -45.000000, T: 99232, Avg. loss: 428.564681
# Total training time: 19.26 seconds.
# -- Epoch 29
# Norm: 8286.79, NNZs: 67600, Bias: -46.000000, T: 102776, Avg. loss: 365.973572
# Total training time: 19.78 seconds.
# -- Epoch 30
# Norm: 8417.99, NNZs: 67600, Bias: -47.000000, T: 106320, Avg. loss: 365.643387
# Total training time: 20.31 seconds.
# -- Epoch 31
# Norm: 8539.75, NNZs: 67600, Bias: -45.000000, T: 109864, Avg. loss: 324.497018
# Total training time: 20.84 seconds.
# -- Epoch 32
# Norm: 8653.12, NNZs: 67600, Bias: -39.000000, T: 113408, Avg. loss: 352.922933
# Total training time: 21.43 seconds.
# -- Epoch 33
# Norm: 8785.61, NNZs: 67600, Bias: -40.000000, T: 116952, Avg. loss: 366.305244
# Total training time: 21.82 seconds.
# -- Epoch 34
# Norm: 8906.23, NNZs: 67600, Bias: -39.000000, T: 120496, Avg. loss: 321.524374
# Total training time: 22.17 seconds.
# -- Epoch 35
# Norm: 9025.11, NNZs: 67600, Bias: -46.000000, T: 124040, Avg. loss: 302.449620
# Total training time: 22.61 seconds.
# -- Epoch 36
# Norm: 9138.24, NNZs: 67600, Bias: -41.000000, T: 127584, Avg. loss: 336.517278
# Total training time: 23.00 seconds.
# -- Epoch 37
# Norm: 9256.34, NNZs: 67600, Bias: -45.000000, T: 131128, Avg. loss: 308.302559
# Total training time: 23.49 seconds.
# -- Epoch 38
# Norm: 9363.62, NNZs: 67600, Bias: -45.000000, T: 134672, Avg. loss: 293.436983
# Total training time: 23.86 seconds.
# -- Epoch 39
# Norm: 9457.47, NNZs: 67600, Bias: -42.000000, T: 138216, Avg. loss: 256.112092
# Total training time: 24.28 seconds.
# -- Epoch 40
# Norm: 9572.63, NNZs: 67600, Bias: -43.000000, T: 141760, Avg. loss: 287.843137
# Total training time: 24.72 seconds.
# -- Epoch 41
# Norm: 9681.44, NNZs: 67600, Bias: -46.000000, T: 145304, Avg. loss: 285.325545
# Total training time: 25.12 seconds.
# -- Epoch 42
# Norm: 9768.06, NNZs: 67600, Bias: -42.000000, T: 148848, Avg. loss: 273.327549
# Total training time: 25.51 seconds.
# -- Epoch 43
# Norm: 9858.35, NNZs: 67600, Bias: -40.000000, T: 152392, Avg. loss: 280.426231
# Total training time: 26.01 seconds.
# -- Epoch 44
# Norm: 9960.65, NNZs: 67600, Bias: -42.000000, T: 155936, Avg. loss: 269.664988
# Total training time: 26.46 seconds.
# Convergence after 44 epochs took 26.46 seconds
# Perceptron(max_iter=50, verbose=True)

# %%
print("Train Set Accuracy: %.2f%%" % (model_p.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_p.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 95.49%
# Test Set Accuracy: 90.19%

# %%
y_pred = model_p.predict(X_test)

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 90.19%

# %%
matrix_confusion(y_test, y_pred)

# %% [markdown]
# ## 4. Percetron Training with alpha and penalty

# %%
model_mp = Perceptron(max_iter=1000, random_state=0, verbose=False, alpha=0.0001)
model_mp.fit(X_train,y_train)

print("Train Set Accuracy: %.2f%%" % (model_mp.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_mp.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 95.49%
# Test Set Accuracy: 90.19%

# %%
y_pred = model_mp.predict(X_test)

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 90.19%

# %%
matrix_confusion(y_test, y_pred)

# %%
model_mp1 = Perceptron(max_iter=1000,  random_state=0, verbose=False, alpha=0.000001, penalty='l2') # Adds L2 penalty
model_mp1.fit(X_train,y_train)

print("Train Set Accuracy: %.2f%%" % (model_mp1.score(X_train, y_train)*100.0))
print("Test Set Accuracy: %.2f%%" % (model_mp1.score(X_test, y_test)*100.0))
# Out:
# Train Set Accuracy: 98.59%
# Test Set Accuracy: 92.03%

# %%
y_pred = model_mp1.predict(X_test)  #pasa cada una de las imágenes de X_test por el modelo

# %%
print("Accuracy: %.2f%%" % (accuracy_score(y_test, y_pred)*100))
# Out:
# Accuracy: 92.03%

# %%
matrix_confusion(y_test, y_pred)

# %% [markdown]
# ## 5. Quantum Machine Learning - QCNN Training

# %%
# Pytorch
import torch, torchvision, torch.utils
from torch import Tensor
from torch import cat
from torch.autograd.grad_mode import no_grad
from torch.utils.data import DataLoader
from torchvision import datasets, transforms
import torch.optim as optim
from torch.nn import (
    Module,
    Conv2d,
    Linear,
    Dropout2d,
    NLLLoss, BCELoss, CrossEntropyLoss, MSELoss,
    MaxPool2d,
    Flatten,
    Sequential,
    ReLU,
)
import torch.nn.functional as F
from torchviz import make_dot
from torchsummary import summary


# Qiskit
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.primitives import Estimator
# from qiskit.opflow import AerPauliExpectation
from qiskit.circuit import Parameter
from qiskit.circuit.library import RealAmplitudes, ZZFeatureMap
from qiskit.quantum_info import DensityMatrix, entanglement_of_formation
from qiskit.visualization import plot_state_city
# from qiskit_machine_learning.neural_networks import TwoLayerQNN
from qiskit_machine_learning.connectors import TorchConnector

# %% [markdown]
# ## Classified Images can be download from:
# https://github.com/contepablod/QCNNCancerClassifier/tree/master/Imagenes_Clasificadas_Random_Split
#
# We read them from local disk:

# %%
train_data = torchvision.datasets.ImageFolder('Imagenes_Clasificadas_Random_Split\\Train', transform=transforms.Compose([transforms.ToTensor()]))
test_data = torchvision.datasets.ImageFolder('Imagenes_Clasificadas_Random_Split\\Test', transform=transforms.Compose([transforms.ToTensor()]))

# %% [markdown]
# Input Tensor Dimension

# %%
train_data[0][0].shape
# Out:
# torch.Size([3, 260, 260])

# %%
train_loader = DataLoader(train_data, shuffle=True, batch_size=1)
test_loader = DataLoader(test_data, shuffle=True, batch_size=1)

# %% [markdown]
# ## Show Images

# %%
# False is no cancer (0) and True, yes (1)
print((train_loader.dataset.class_to_idx))
# Out:
# {'False': 0, 'True': 1}

# %%
n_samples_show = 6

data_iter = iter(train_loader)
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 10))

while n_samples_show > 0:
    images, targets = data_iter.__next__()

    axes[n_samples_show - 1].imshow(images[0, 0].numpy().squeeze(), cmap=plt.cm.rainbow)
    axes[n_samples_show - 1].set_xticks([])
    axes[n_samples_show - 1].set_yticks([])
    axes[n_samples_show - 1].set_title(f"Labeled: {targets[0].item()}")

    n_samples_show -= 1

# %% [markdown]
# ## How a Hybrid Neural Networks works?

# %%
Image(url='https://raw.githubusercontent.com/contepablod/QCNNCancerClassifier/master/hybridnetwork.png')
# Out:
# <img src="https://raw.githubusercontent.com/contepablod/QCNNCancerClassifier/master/hybridnetwork.png"/>

# %% [markdown]
# ### Quantum Instance Declaration

# %%
from qiskit_aer import AerSimulator

# Replace QuantumInstance with AerSimulator
simulator = AerSimulator(method="statevector")

# %% [markdown]
# ## Interacion between Quantum Node and Convolutional Neural Network

# %%
Image(url='https://raw.githubusercontent.com/contepablod/QCNNCancerClassifier/master/neuralnetworkQC.png')
# Out:
# <img src="https://raw.githubusercontent.com/contepablod/QCNNCancerClassifier/master/neuralnetworkQC.png"/>

# %% [markdown]
# ### Quantum Neural Network Definition

# %%
from qiskit.primitives import Estimator
from qiskit_machine_learning.neural_networks import EstimatorQNN

def create_qnn():
    # Define the feature map and ansatz
    feature_map = ZZFeatureMap(2)
    ansatz = RealAmplitudes(2, reps=1)

    # Use EstimatorQNN instead of TwoLayerQNN with AerPauliExpectation
    qnn = EstimatorQNN(
        circuit=feature_map.compose(ansatz),  # Combine feature map and ansatz
        input_params=feature_map.parameters,  # Input parameters for the feature map
        weight_params=ansatz.parameters       # Weight parameters for the ansatz
    )
    return qnn

# %%
qnn = create_qnn()
# Out:
# C:\Users\Danny\AppData\Local\Temp\ipykernel_20848\1716803944.py:10: DeprecationWarning: V1 Primitives are deprecated as of qiskit-machine-learning 0.8.0 and will be removed no sooner than 4 months after the release date. Use V2 primitives for continued compatibility and support.
#   qnn = EstimatorQNN(

# %% [markdown]
# #### Circuit Graph

# %%
qnn.circuit.draw(output='mpl')

# %% [markdown]
# #### ZZFeatureMap Graph / Second-order Pauli-Z evolution circuit.

# %%
qnn.circuit.decompose().draw(output='mpl')

# %% [markdown]
# #### RealAmplitudes Graph / Real-Amplitudes 2-local circuit.

# %%
qnn.circuit.decompose().draw(output='mpl')

# %% [markdown]
# ### Quantum Entaglement Check

# %% [markdown]
# There are CNOT gates in the circuits like ZZFeatureMap and RealAmplitudes, thus the QNN makes use of entanglement.<br>
# <br>
# Probably in 99% of cases there is entanglement but not always (e.g. if the inputs to CNOTs are in only |0> or |1>), thus at the end is parameter dependant

# %% [markdown]
# Let's check the circuit parameters:

# %%
qnn.circuit.parameters
# Out:
# ParameterView([ParameterVectorElement(x[0]), ParameterVectorElement(x[1]), ParameterVectorElement(θ[0]), ParameterVectorElement(θ[1]), ParameterVectorElement(θ[2]), ParameterVectorElement(θ[3])])

# %% [markdown]
# Let's generate parameters randomly:

# %%
params = np.random.uniform(-1, 1, len(qnn.circuit.parameters))
params
# Out:
# array([ 0.54098743,  0.12164547, -0.52550223,  0.44895085, -0.69601079,
#        -0.63789806])

# %% [markdown]
# Let's bind parameters, get the Circuit Density Matrix and get the purity state of it:

# %%
rho_01 = DensityMatrix.from_instruction(qnn.circuit.assign_parameters(params))

# %%
plot_state_city(rho_01.data, title='Density Matrix', figsize=(12,6))

# %%
gamma_p = rho_01.purity()
display(rho_01.draw('latex', prefix='\\rho_p = '))
print("State purity: ", np.round(np.real(gamma_p), 3))
# Out:
# $$
# \rho_p =
# \begin{bmatrix}
# 0.0775571613 & 0.1423950623 + 0.0662211862 i & 0.1540114061 - 0.0157629108 i & -0.1400243401 - 0.0574947857 i  \\
#  0.1423950623 - 0.0662211862 i & 0.3179796534 & 0.2693062093 - 0.1604413887 i & -0.3061760789 + 0.0139974734 i  \\
#  0.1540114061 + 0.0157629108 i & 0.2693062093 + 0.1604413887 i & \frac{2 \cdot 2^{\frac{7}{11}} \cdot 3^{\frac{79}{99}} \cdot 5^{\frac{127}{396}} \cdot 7^{\frac{245}{396}}}{135} & -0.2663720536 - 0.1426308517 i  \\
#  -0.1400243401 + 0.0574947857 i & -0.3061760789 - 0.0139974734 i & -0.2663720536 + 0.1426308517 i & 0.2954268287  \\
#  \end{bmatrix}
# $$
# State purity:  1.0

# %%
print(f'{entanglement_of_formation(rho_01):.4f}')
# Out:
# 0.8993

# %% [markdown]
# ### Pytorch Neural Net Definition

# %%
# Red Neuronal en Pytorch
class Net(Module):
    def __init__(self, qnn):
        super().__init__()
        self.conv1 = Conv2d(3, 128, kernel_size=5)
        self.conv2 = Conv2d(128, 128, kernel_size=3)
        self.dropout = Dropout2d()
        self.fc1 = Linear(508032, 128)
        self.fc2 = Linear(128, 2) # QNN binary input
        self.qnn = TorchConnector(qnn) # use TorchConnector to bind quantum node and classic convolutional layers
        self.fc3 = Linear(1, 1)  # Quantum Circuit Output

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.max_pool2d(x, 2)
        x = F.relu(self.conv2(x))
        x = F.max_pool2d(x, 2)
        x = self.dropout(x)
        x = x.view(x.shape[0], -1)
        x = F.relu(self.fc1(x))
        x = self.fc2(x)
        x = self.qnn(x)  # QNN in foward section
        x = self.fc3(x)
        return cat((x, 1 - x), -1)

model = Net(qnn)

# %%
import torch
print(torch.cuda.is_available())  # Should return True
print(torch.cuda.device_count())  # Should return the number of GPUs
print(torch.cuda.get_device_name(0))  # Should return the name of your GPU
# Out:
# False
# 0

# %% [markdown]
# ### GPU Model Activation

# %%
my_device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(my_device)  # Should return cuda:0 if GPU is available, otherwise cpu
# Out:
# cpu

# %%
model = model.to(my_device)

# %% [markdown]
# ### Show Model

# %%
print(model)
# Out:
# Net(
#   (conv1): Conv2d(3, 128, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1))
#   (dropout): Dropout2d(p=0.5, inplace=False)
#   (fc1): Linear(in_features=508032, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=2, bias=True)
#   (qnn): TorchConnector()
#   (fc3): Linear(in_features=1, out_features=1, bias=True)
# )

# %%
summary(model, (3, 260, 260), batch_size=-1, device='cuda')  # Use 'cuda' for GPU or 'cpu' for CPU
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[100], line 1
# ----> 1 summary(model, (3, 260, 260), batch_size=-1, device=my_device)
#
# File c:\Users\Danny\anaconda3\envs\ipcv\Lib\site-packages\torchsummary\torchsummary.py:44, in summary(model, input_size, batch_size, device)
#      37     if (
#      38         not isinstance(module, nn.Sequential)
#      39         and not isinstance(module, nn.ModuleList)
#      40         and not (module == model)
#      41     ):
#      42         hooks.append(module.register_forward_hook(hook))
# ---> 44 device = device.lower()
#      45 assert device in [
#      46     "cuda",
#      47     "cpu",
#      48 ], "Input device is not valid, please specify 'cuda' or 'cpu'"
#      50 if device == "cuda" and torch.cuda.is_available():
#
# AttributeError: 'torch.device' object has no attribute 'lower'

# %%
# dummy_tensor = next(iter(train_loader))[0].to('cuda')
# make_dot(model(dummy_tensor), params=dict(list(model.named_parameters())), show_saved=True, show_attrs=True).render("rnn_torchviz", format="png")
#Image('https://raw.githubusercontent.com/contepablod/QCNNCancerClassifier/master/rnn_torchviz.png')
Image(r'rnn_torchviz.png', width=2000, height=2250)

# %% [markdown]
# ### Optimisation and Loss Function Definition, and finally training

# %%
optimizer = optim.Adam(model.parameters(), lr=0.00001)
loss_func = CrossEntropyLoss().to(my_device)


epochs = 50
model.train()

loss_list = []
total_accuracy = []

for epoch in range(epochs):
    correct = 0
    total_loss = []
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad(set_to_none=True)
        output = model(data.to(my_device))  # Forward pass, Data to GPU
        loss = loss_func(output, target.to(my_device)) #Labels to GPU
        loss.backward()  # Backward pass
        optimizer.step()
        total_loss.append(loss.item())
        train_pred = output.argmax(dim=1, keepdim=True)
        correct += train_pred.eq(target.to(my_device).view_as(train_pred)).sum().item()
    loss_list.append(sum(total_loss) / len(total_loss))
    accuracy = 100 * correct / len(train_loader)
    total_accuracy.append(accuracy)
    print(f"Training [{100.0 * (epoch + 1) / epochs:.0f}%]\tLoss: {loss_list[-1]:.4f}\tAccuracy: {accuracy:.2f}%")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[101], line 18
#      16 output = model(data.to(my_device))  # Forward pass, Data to GPU
#      17 loss = loss_func(output, target.to(my_device)) #Labels to GPU
# ---> 18 loss.backward()  # Backward pass
#      19 optimizer.step()
#      20 total_loss.append(loss.item())
#
# File c:\Users\Danny\anaconda3\envs\ipcv\Lib\site-packages\torch\_tensor.py:570, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     567     # All strings are unicode in Python 3.
#     568     return torch._tensor_str._str(self, tensor_contents=tensor_contents)
# --> 570 def backward(
#     571     self, gradient=None, retain_graph=None, create_graph=False, inputs=None
#     572 ):
#     573     r"""Computes the gradient of current tensor wrt graph leaves.
#     574
#     575     The graph is differentiated using the chain rule. If the tensor is
#    (...)    614             used to compute the :attr:`tensors`.
#     615     """
#     616     if has_torch_function_unary(self):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Convergence Plot

# %%
fig, ax1 = plt.subplots()
ax1.plot(loss_list, 'g-')
ax2 = ax1.twinx()
ax2.plot(total_accuracy, 'b')
plt.title("Hybrid NN Training Convergence", color='red')
ax1.set_xlabel("Training Iterations")
ax1.set_ylabel("Cross Entropy Loss", color='g')
ax2.set_ylabel("Accuracy (%)", color='b')
plt.show()

# %% [markdown]
# ### Save Model

# %%
torch.save(model.state_dict(), "model.pt")

# %% [markdown]
# ### Load Model to prediction

# %%
qnn1 = create_qnn()
model1 = Net(qnn1)
model1.load_state_dict(torch.load("model.pt"))
model1= model1.to(my_device)

# %%
batch_size=1

model1.eval()
pred_targets = []
test_targets= []
with no_grad():

    correct = 0
    for batch_idx, (data, target) in enumerate(test_loader):
        output = model1(data.to(my_device))
        if len(output.shape) == 1:
            output = output.reshape(1, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)
        pred_targets.append(pred.item())
        test_targets.append(target.item())
        correct += pred.eq(target.to(my_device).view_as(pred)).sum().item()

        loss = loss_func(output, target.to(my_device))
        total_loss.append(loss.item())

    print(f"Performance on test data:\n\tLoss: {sum(total_loss) / len(total_loss):.4f}\n\tAccuracy: {100 * correct / len(test_loader) / batch_size:.2f}%")
# Out:
# Performance on test data:
# 	Loss: 0.0438
# 	Accuracy: 98.76%

# %% [markdown]
# ### Show predicted images

# %%
from PIL import Image

n_samples_show = 6
count = 0
fig, axes = plt.subplots(nrows=1, ncols=n_samples_show, figsize=(10, 3))

model1.eval()
with no_grad():
    for batch_idx, (data, target) in enumerate(test_loader):
        if count == n_samples_show:
            break
        output = model1(data.to(my_device)[0:1])
        if len(output.shape) == 1:
            output = output.reshape(3, *output.shape)

        pred = output.argmax(dim=1, keepdim=True)

        axes[count].imshow(torchvision.transforms.ToPILImage(mode='RGB')(data[0].squeeze()), cmap=plt.cm.rainbow)

        axes[count].set_xticks([])
        axes[count].set_yticks([])
        axes[count].set_title("Predicted {}".format(pred.item()))

        count += 1

# %%
matrix_confusion(test_targets, pred_targets)

# %% [markdown]
# # Observations:

# %% [markdown]
# - The hybrid neural network has better accuracy than the perceptron. Recall that the input to the perceptron is a matrix representing grayscale images while the input to the neural network is a [3, 260, 260] tensor.
#
# - By vectorizing the image, the Perceptron losses information about the image, although it can be reconstructed. The neural network works with the complete information of the image.
#
# - Could be possible to optimize hyperparameters and architecture of the quantum convolutional neural network.
#
# - The quantum circuit could be improved with more layers.
#
# - Quantum Entaglement is, at the end, parameter binded.
#
# - This model is built only with educational purposes.

# %% [markdown]
# # Referencias

# %% [markdown]
# 1. Hybrid quantum-classical Neural Networks with PyTorch and Qiskit: https://qiskit.org/textbook/ch-machine-learning/machine-learning-qiskit-pytorch.html

# %% [markdown]
# 2. Torch Connector and Hybrid QNNs: https://qiskit.org/documentation/machine-learning/tutorials/05_torch_connector.html

# %% [markdown]
# 3. The Quantum Convolution Neural Network: https://qiskit.org/documentation/machine-learning/tutorials/11_quantum_convolutional_neural_networks.html

# %% [markdown]
# 4. Clasificador de Cáncer de Esófago: https://github.com/AnIsAsPe/ClassificadorCancerEsofago

# %% [markdown]
# 5. Machine Learning & IA for the Working Analyst - Colegio de Mátematicas Bourbaki - Mexico
# - https://www.colegio-bourbaki.com/
# - LinkedIn: Colegio Bourbaki

# %% [markdown]
# 6. Qiskit Slack Channel (qiskit.slack.com) - Special Thanks to Owen Lockwood & Anton Dekusar
